# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
# Synthetic data creation
data = pd.read_csv("sales-data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Sales   365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
data.head()
# Out:
#          Date      Sales
# 0  2023-01-01  52.490142
# 1  2023-01-02  50.896298
# 2  2023-01-03  53.565075
# 3  2023-01-04  56.501669
# 4  2023-01-05  51.540170

# %%
# Step 1: Convert 'Date' column to datetime type (if it's not already)
data['Date'] = pd.to_datetime(data['Date'])

# Step 2: Set 'Date' as index
data.set_index('Date', inplace=True)

# Step 3: (Optional) Sort index if needed
data.sort_index(inplace=True)

# Now `df` will have a DateTimeIndex
print(data.head())
print(data.index)  # Will show: DatetimeIndex([...])
# Out:
#                 Sales
# Date
# 2023-01-01  52.490142
# 2023-01-02  50.896298
# 2023-01-03  53.565075
# 2023-01-04  56.501669
# 2023-01-05  51.540170
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', name='Date', length=365, freq=None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2023-01-01 to 2023-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   365 non-null    float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %%
# Visualize data
data.plot(figsize=(10, 4), title="Daily Sales Data")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(data)

# Create supervised data
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 30  # Using past 30 days to predict next day
X, y = create_sequences(scaled_sales, seq_length)

# Train-test split (80%-20%)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()
#return_sequences -- Enable LongTerm Memory
model.add(LSTM(50, activation='relu', input_shape=(seq_length, 1), return_sequences=True))
model.add(LSTM(25, activation='relu'))
model.add(Dense(1))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 30, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 25)             │         7,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,026 (70.41 KB)
#  Trainable params: 18,026 (70.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.1836 - val_loss: 0.4836
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1137 - val_loss: 0.0678
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0274 - val_loss: 0.0417
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0110 - val_loss: 0.0397
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0098 - val_loss: 0.0289
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0113 - val_loss: 0.0447
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0105 - val_loss: 0.0373
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0095 - val_loss: 0.0323
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0091 - val_loss: 0.0290
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0086 - val_loss: 0.0124
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0088 - val_loss: 0.0058
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0095 - val_loss: 0.0153
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0080 - val_loss: 0.0040
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0084 - val_loss: 0.0095
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0081 - val_loss: 0.0068
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0089 - val_loss: 0.0050
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0093 - val_loss: 0.0049
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0070 - val_loss: 0.0046
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0086 - val_loss: 0.0071
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0082 - val_loss: 0.0044
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0073 - val_loss: 0.0041
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0077 - val_loss: 0.0066
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0084 - val_loss: 0.0110
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0083 - val_loss: 0.0117
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0087 - val_loss: 0.0042
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0097 - val_loss: 0.0082
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0083 - val_loss: 0.0041
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0072 - val_loss: 0.0043
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0080 - val_loss: 0.0046
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0088 - val_loss: 0.0139
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0078 - val_loss: 0.0111
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0077 - val_loss: 0.0049
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0075 - val_loss: 0.0049
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0080 - val_loss: 0.0052
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0085 - val_loss: 0.0041
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0078 - val_loss: 0.0042
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0093 - val_loss: 0.0042
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0086 - val_loss: 0.0057
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0089 - val_loss: 0.0041

# %%
# Predictions
y_pred = model.predict(X_test)

# Rescale to original values
y_test_orig = scaler.inverse_transform(y_test)
y_pred_orig = scaler.inverse_transform(y_pred)

# Calculate metrics
rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred_orig))
mae = mean_absolute_error(y_test_orig, y_pred_orig)

print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")

# Plot Actual vs Predicted
plt.figure(figsize=(10, 5))
plt.plot(data.index[-len(y_test_orig):], y_test_orig, label="Actual Sales")
plt.plot(data.index[-len(y_test_orig):], y_pred_orig, label="Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# RMSE: 2.37
# MAE: 1.95

# %%
last_sequence = scaled_sales[-seq_length:]
forecast_days = 7
forecast = []

for _ in range(forecast_days):
    input_seq = last_sequence[-seq_length:].reshape(1, seq_length, 1)
    pred = model.predict(input_seq)
    forecast.append(pred[0,0])
    last_sequence = np.append(last_sequence, pred, axis=0)

# Inverse transform predictions
forecast_orig = scaler.inverse_transform(np.array(forecast).reshape(-1,1))

# Forecast dates
forecast_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=forecast_days)

# Plot Forecast
plt.figure(figsize=(10, 4))
plt.plot(data.index, data['Sales'], label='Historical Sales')
plt.plot(forecast_dates, forecast_orig, marker='o', linestyle='--', label='Forecasted Sales', color='red')
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Sales Forecast for Next 7 Days")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
